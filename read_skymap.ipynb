# %%
###################################################
#            Run this only once !!                #
# This will download the skymaps from GWTC-3.0    # 
# From Zenodo: https://zenodo.org/records/5546663 #
###################################################
# !wget https://zenodo.org/records/5546663/files/skymaps.tar.gz
# !tar -xvzf skymaps.tar.gz

# %%
from astropy.io import fits

test_fit = fits.open('skymaps/IGWN-GWTC3p0-v1-GW200308_173609_PEDataRelease_cosmo_reweight_C01:IMRPhenomXPHM.fits')

# %%
test_fit.info()
# Out:
# Filename: skymaps/IGWN-GWTC3p0-v1-GW200308_173609_PEDataRelease_cosmo_reweight_C01:IMRPhenomXPHM.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1                1 BinTableHDU     41   16896R x 5C   [K, D, D, D, D]
